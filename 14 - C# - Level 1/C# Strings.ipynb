// %% [markdown]
// # Hello C# string Methods !

// %%
// Length
string s = "sfsfdfdsfdsffdsafr";
Console.WriteLine(s.Length);
// Out:
// 18

// %%
// you can access char of string using index 
string s = "sfsfdfdsfdsffdsafr";
Console.WriteLine(s[1]);
// Out:
// f

// %%
// Format --> to store fromat in variable 
// String.Format("formating{0}{1}",arg to pass ) --> return string after formating 
string Str = "Hello string!";
Console.WriteLine(String.Format("This is test \" {0} \" ", Str)); //Composite Formatting
Console.WriteLine("This is test \" {0} \" ", Str);

string Text = $"Hello this is \"{Str}\" modern formating!"; //String Interpolation.
Console.WriteLine(Text);

string Foramting = "This is test \" {0} \" "; //Composite Formatting
Console.WriteLine(Foramting, Str);

string CF = String.Format("Hi {0}(composite formating)", Str);//Composite Formatting
string IF = String.Format($"Hi {Str}");//String Interpolation.
Console.WriteLine(CF);
Console.WriteLine(IF);
// Out:
// This is test " Hello string! "
// This is test " Hello string! "
// Hello this is "Hello string!" modern formating!
// This is test " Hello string! "
// Hi Hello string!(composite formating)
// Hi Hello string!

// %%
// split() string
string Record = "Name#//#Balance#//#Id";
string [] SplitedString = Record.Split("#//#");

Console.WriteLine(SplitedString[0]);
Console.WriteLine(SplitedString[1]);
Console.WriteLine(SplitedString[2]);
// Out:
// Name
// Balance
// Id

// %%
// Substring() --> substr() in c++ 
string Record = "Name#//#Balance#//#Id";

string FromIndex = Record.Substring(0, 4); // StartIndex,NumOfCharsToCut 
Console.WriteLine(FromIndex);

string FromIndexToEndString = Record.Substring(7); // StartIndex --> will cut the string from start to end 
Console.WriteLine(FromIndexToEndString);
// Out:
// Name
// #Balance#//#Id

// %% [markdown]
// | القيمة    | معناها                        |
// | --------- | ----------------------------- |
// | 0         | النصان متساويان               |
// | أقل من 0  | `str2` أصغر أبجديًا من `str1` |
// | أكبر من 0 | `str2` أكبر أبجديًا من `str1` |

// %%
// Compare() --> returns num (-1,0,1)
//Lexicographically أبجديًا
string S1 = "cat";
string S2 = "cat";

Console.WriteLine(String.Compare(S1, S2)); // 0 --> The Same Length


string S3 = "Boggy";
string S4 = "Bog";

Console.WriteLine(String.Compare(S3, S4)); // Str1 > Str2 

string s5 = "lol";
string s6 = "LOLOLO";


Console.WriteLine(String.Compare(s5, s6)); // Str1 < Str2
// Out:
// 0
// 1
// -1

// %%
string H1 = "HELLO";
string h1 = "hello";

Console.WriteLine(string.Compare(H1, h1,true)); // true --> make the compare case insensitive
// Out:
// 0

// %%
// CompareTo()
string H1 = "HELLO";
string h1 = "hello";

Console.WriteLine(H1.CompareTo(h1)); // case sensitive
// Out:
// 1

// %%
// Small example on compare
string Default = "yes";
string userinput = "yes";
string userinput2 = "Yes";

if(String.Compare(Default, userinput,true) ==0) // matches
{
    Console.WriteLine("User Entered yes of Yes");
}
// Out:
// User Entered yes of Yes

// %%
// Replace() --> (old value , new value) replace the old value with the new value 
string s = "Hi Loay !";
s = s.Replace("Loay", "Jana");

Console.WriteLine(s);
// Out:
// Hi Jana !

// %%
// Contains()
string str = "Hello Adel";
Console.WriteLine(str.Contains("Hello")); // return true if(string/char) in the string 
Console.WriteLine(str.Contains('h'));
// Out:
// True
// False

// %% [markdown]
// | الميثود | الوظيفة              |
// | ------- | -------------------- |
// | Join    | دمج عناصر مع فاصل    |
// | Concat  | دمج النصوص بدون فاصل |

// %%
// Join() --> concat elements with sperator (sperator , Arr_List_etc)
string[] Arr = { "osama", "ahmed", "maha" };
string res2 = String.Join("-->", Arr);
Console.WriteLine(res2);

int [] Arr2 ={1,2,3,4,5,6,7};
string res = String.Join("#//#", Arr2);
Console.WriteLine(res);

string s = String.Concat("d", "b"); // add 2 strings without sperator 
Console.WriteLine(s);
// Out:
// osama-->ahmed-->maha
// 1#//#2#//#3#//#4#//#5#//#6#//#7
// db

// %%
// Trim()
string s = "    jk     ";
Console.WriteLine(s);
Console.WriteLine(s.Trim()); // --> removes the ws from left and rigth 
Console.WriteLine(s.TrimStart()); // --> removes the ws from left 
Console.WriteLine(s.TrimEnd());// --> removes the ws from right
// Out:
//     jk
// jk
// jk
//     jk

// %%
// EndsWith() --> return true if (string/char) ends with parameter 
string H = "Hello";
Console.WriteLine(H.EndsWith('!'));
Console.WriteLine(H.EndsWith('o'));
Console.WriteLine(H.EndsWith("o"));
// Out:
// False
// True
// True

// %%
// StartsWith() --> is the string starts with 'char' , return bool value 
string H = "Hello";
Console.WriteLine(H.StartsWith('!'));
Console.WriteLine(H.StartsWith('o'));
Console.WriteLine(H.StartsWith("H"));
// Out:
// False
// False
// True

// %%
// IndexOf() --> first occurence 
string str = "Lalaaaaa";
Console.WriteLine(str.IndexOf("a", 2)); // start from specific index instead of index 0 
Console.WriteLine(str.IndexOf("a")); // return the first occurence of that char 
Console.WriteLine(str.IndexOf("la")); // return the first occurence of that string 
Console.WriteLine(str.IndexOf('L')); // return the first occurence of that char
// Out:
// 3
// 1
// 2
// 0

// %%
// LastIndexOf() --> the last occurence 
string str = "iam lala";
Console.WriteLine("{0} , {1}", str.LastIndexOf('a'), str.Length - 1);

str = "aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa";
Console.WriteLine("The Last Occurence {0} , {1}", str.LastIndexOf('a'), str.Length - 1);

Console.WriteLine("The First Occurence {0} , {1}", str.IndexOf('a'), str.Length - 1);
// Out:
// 7 , 7
// The Last Occurence 37 , 37
// The First Occurence 0 , 37

// %%
// Remove()
using System.Globalization;

string s= "Hello World!";
s = s.Remove(s.IndexOf('W')); // remove starting to index to untill the end
Console.WriteLine(s);

s = s.Substring(0, 2); // (start , num of chars) --> it doesn't cut it sclicling string from the total string

Console.WriteLine(s);

s = s.Remove(0, 1);// (start , num of chars) 
Console.WriteLine(s);
// Out:
// Hello
// He
// e

// %%
// ToUpper() --> converts all chars of string to uppercase 
string s = "hardware"; 
s = s.ToUpper();
Console.WriteLine(s);
// Out:
// HARDWARE

// %%
string s = "HARDWARE";// --> converts all chars of string to lowercase 
s = s.ToLower();
Console.WriteLine(s);
// Out:
// hardware

// %%
// خلي بالك لو انت مغيرتش سترنج اصلي با سترنج الي فيه بادمج سترنج اصلي متاثرش بحاجه //

// PadLeft(Total Width,Padding char) // add specific (space,char) with string to make string totally reaches the length(Total width)
// Default is space 
string s = "1"; // l=1 
s = s.PadLeft(2,'0'); // (the number of spaces , the char to insert to fill the space if it is isn't the desired length ) --> 2 is the desired length 
Console.WriteLine(s);
// Out:
// 01

// %%
string[] arr = { "osama", "sama", "maha" };

for(int i=0; i<arr.Length; i++)
{
    Console.WriteLine(arr[i].PadLeft(10,')'));
}
// Out:
// )))))osama
// ))))))sama
// ))))))maha

// %%
string n = "100"; // L=3 , D =5 , so it will add 2 zeros --> to left 
Console.WriteLine(n.PadLeft(5, '0'));
// Out:
// 00100

// %%
// PadRigth()
string n = "111"; // L=3 , D =5 , so it will add 2 zeros --> to rigth 
Console.WriteLine(n.PadRight(5, '0'));
// Out:
// 11100

// %%
string S1 = "Eyan";

Console.WriteLine("The Length is: {0}", S1.Length);
Console.WriteLine($"The Deired Length is: {10}");
Console.WriteLine($"So It Will Add 5 Pad To Achieve The 10 Length: {S1.PadLeft(10, '_')}" );
// Out:
// The Length is: 4
// The Deired Length is: 10
// So It Will Add 5 Pad To Achieve The 10 Length: ______Eyan

// %%
Console.Write("Write".PadRight(20, '.'));
Console.WriteLine(" The Answer");
// Out:
// Write............... The Answer

// %%
// ToArrayChar() --> converts string to array of chars 
string str = "Hello,iam osama!";
char[] ArrOfChars = str.ToCharArray();
Console.WriteLine(ArrOfChars.GetType());

for (byte i = 0; i < ArrOfChars.Length; i++)
{
    Console.Write($"{ArrOfChars[i]}".PadRight(2, '-'));
}
Console.WriteLine();
Console.WriteLine(String.Join("#", ArrOfChars));
// Out:
// System.Char[]
// H-e-l-l-o-,-i-a-m- -o-s-a-m-a-!-
// H#e#l#l#o#,#i#a#m# #o#s#a#m#a#!

// %%
// Insert() --> (start index , value to insert )
string hi = "Hello";
hi = hi.Insert( hi.Length," Osama");
Console.WriteLine(hi);

hi = hi.Insert(hi.Length, "!");
Console.WriteLine(hi);
// Out:
// Hello Osama
// Hello Osama!
